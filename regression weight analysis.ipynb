# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### All data

# %%
raw_signal_weights = [0.00478842, 0.00086258, 0.00426597, 0.00314442, -0.00778936, -0.02215246, -0.01716786, 
                      -0.00828033, -0.00177534, 0.00717033, 0.01368301, 0.0254106, 0.03835799, 0.03576535,
                      0.0404046, 0.05183366, 0.05600024]

adm_reconstruction_weights = [7.29903781e-03, 4.37537673e-03, 1.36516852e-03, -3.53013426e-03,
                              -1.26461030e-02, -1.99541074e-02, -1.53579970e-02, -2.25107445e-03,
                              7.44859799e-03, 3.00756771e-02, 5.67019817e-02, 1.32433176e-01,
                              2.39104477e-01, 3.81447416e-01, 8.78149019e-01, 1.59401617e+00,
                              2.94125825e+00]
frequencies = [0.5, 0.625, 0.75, 0.875, 1., 1.125, 1.25, 1.375, 1.5, 1.625, 1.75, 1.875, 2., 2.125, 2.25, 2.375, 2.5]

# %%
plt.bar(frequencies, raw_signal_weights, width=0.1)
plt.title('Raw PPG weights')
# Out:
# Text(0.5, 1.0, 'Raw PPG weights')

# %%
plt.bar(frequencies, adm_reconstruction_weights, width=0.1)
plt.title('Reconstructed signal weights')
# Out:
# Text(0.5, 1.0, 'Reconstructed signal weights')

# %% [markdown]
# ### Subject 9

# %%
raw_signal_weights = [-0.0036508, 0.00308346, -0.00088888, -0.00160844, 0.00645522, 0.00150622,
                      -0.00672154, -0.00401984, -0.00110337, -0.00218342, -0.00253833, 0.01268405,
                      0.01273913, 0.00433516, 0.00950397, 0.00854658, -0.00803234]


adm_reconstruction_weights = [-6.34257686e-03, 5.84744564e-04, -1.76178039e-03, -4.13672938e-03,
                              4.38350371e-03, -8.00546484e-03, -1.69553718e-02, -1.16487801e-02,
                              6.92811295e-03, -1.14020001e-02, 2.30668787e-02, 9.80527617e-02,
                              1.55131570e-01, 3.12832191e-01, 8.00729621e-01, 1.30919644e+00,
                              2.03699543e+00]

frequencies = [0.5, 0.625, 0.75, 0.875, 1., 1.125, 1.25, 1.375, 1.5, 1.625, 1.75, 1.875, 2., 2.125, 2.25, 2.375, 2.5]

# %%
plt.bar(frequencies, raw_signal_weights, width=0.1)
plt.title('Raw PPG weights')
# Out:
# Text(0.5, 1.0, 'Raw PPG weights')

# %%
plt.bar(frequencies, adm_reconstruction_weights, width=0.1)
plt.ylim(0, 0.1)
plt.title('Reconstructed signal weights')
# Out:
# Text(0.5, 1.0, 'Reconstructed signal weights')
